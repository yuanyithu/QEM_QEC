# %%
import jax.numpy as jnp
import numpy as np

# %%
p1 = 1e-8
print(np.log10(1+12*p1)*3000)
# Out:
# 0.00015634600402211697

# %%
A = set([i+1 for i in range(10)])

# %%
A.remove(10)

# %%
A.remove(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 A.remove(100)
#
# KeyError: 100

# %%
A.discard(100)

# %%
A.
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
1 in A
# Out:
# True

# %%
A
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
a = [1,3,2,2,3]
a.sort()

# %%
a
# Out:
# [1, 2, 2, 3, 3]

# %%
a = dict()

# %%
for j in range(11,10):
    print(j)

# %%
a = [1,3,2]
new = sorted(a)

# %%
new
# Out:
# [1, 2, 3]

# %%
a = set()

# %%
a
# Out:
# set()

# %%
a.add(1)

# %%
a
# Out:
# {1}

# %%
a.pop()
# Out:
# 1

# %%
a.discard(2)

# %%
1 in a
# Out:
# True

# %%
b = dict()

# %%
b[1] = 2

# %%
A = sorted(b.values())

# %%
A
# Out:
# [2]
