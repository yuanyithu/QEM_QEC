# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
import jax.numpy as jnp
import jax.random as random
import jax

# %%
Q = jnp.zeros([8,2],dtype=jnp.complex64)
Q
# Out:
# Array([[0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j]], dtype=complex64)

# %%
Q1 = Q.at[0,0].set(1)

# %%
Q1
# Out:
# Array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j]], dtype=complex64)

# %%
Q2 = Q1.at[7,1].set(1)
Q2
# Out:
# Array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j],
#        [0.+0.j, 1.+0.j]], dtype=complex64)
